# %%
# %matplotlib inline
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd   
import glob
import os

# %% [markdown]
# # DQN

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/dqn/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)
b = [x for x in range(len(a))]


plt.figure(figsize=(12,7))
plt.plot(b, a['sp'], c='g', label = 'S P')
plt.plot(b, a['pv'], c='r', label = 'P V')
plt.plot(b, a['cv'], c='b', label = 'C V')
plt.legend()
plt.savefig('dqn_full.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/dqn\30_10_2020_12_01_04.csv

# %% [markdown]
# # Sarsa

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/sarsa/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)
b = [x for x in range(len(a))]

plt.figure(figsize=(12,7))
plt.plot(b, a['sp'], c='g', label = 'S P')
plt.plot(b, a['pv'], c='r', label = 'P V')
plt.plot(b, a['cv'], c='b', label = 'C V')
plt.legend()
plt.savefig('sarsa_full.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/sarsa\30_10_2020_14_05_08.csv

# %% [markdown]
# # CEM

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/cem/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)
b = [x for x in range(len(a))]

plt.figure(figsize=(12,7))
plt.plot(b, a['sp'], c='g', label = 'S P')
plt.plot(b, a['pv'], c='r', label = 'P V')
plt.plot(b, a['cv'], c='b', label = 'C V')
plt.legend()
plt.savefig('cem_full.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/cem\30_10_2020_15_18_27.csv

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/plc_pid/data/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)
b = [x for x in range(len(a))]

plt.figure(figsize=(12,7))
plt.plot(b, a['sp'], c='g', label = 'S P')
plt.plot(b, a['pv'], c='r', label = 'P V')
plt.plot(b, a['cv'], c='b', label = 'C V')
plt.legend()
plt.savefig('plc_full.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/plc_pid/data\11_11_2020_01_54_07.csv

# %% [markdown]
# # DQN

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/dqn/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)

a['error'] = abs(a['sp'] - a['pv'])

first_transition = a.head(1500).tail(1000)
mean = first_transition["error"].mean()
print("first transition mean : " , mean)

last_transition = a.tail(1000)
mean = last_transition["error"].mean()
print("last transition mean : " , mean)
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(10,6))
plt.plot(b, first_transition['error'], c='r')
plt.savefig('dqn_first_transition.png')
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(10,6))
plt.plot(b, last_transition['error'], c='r')
plt.savefig('dqn_last_transition.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/dqn\30_10_2020_12_01_04.csv
# first transition mean :  54.38463716255775
# last transition mean :  21.585676377250973

# %% [markdown]
# # Sarsa

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/sarsa/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)

a['error'] = abs(a['sp'] - a['pv'])

first_transition = a.head(1500).tail(1000)
mean = first_transition["error"].mean()
print("first transition mean : " , mean)

last_transition = a.tail(1000)
mean = last_transition["error"].mean()
print("last transition mean : " , mean)
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(10,6))
plt.plot(b, first_transition['error'], c='r')
plt.savefig('sarsa_first_transition.png')
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(10,6))
plt.plot(b, last_transition['error'], c='r')
plt.savefig('sarsa_last_transition.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/sarsa\30_10_2020_14_05_08.csv
# first transition mean :  0.7924464821402398
# last transition mean :  0.7740572341704864

# %% [markdown]
# # CEM

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/cem/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)

a['error'] = abs(a['sp'] - a['pv'])

first_transition = a.head(1500).tail(1000)
mean = first_transition["error"].mean()
print("first transition mean : " , mean)

last_transition = a.tail(1000)
mean = last_transition["error"].mean()
print("last transition mean : " , mean)
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(10,6))
plt.plot(b, first_transition['error'], c='r')
plt.savefig('cem_first_transition.png')

b = [x for x in range(len(first_transition))]

plt.figure(figsize=(10,6))
plt.plot(b, last_transition['error'], c='r')
plt.savefig('cem_last_transition.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/cem\30_10_2020_15_18_27.csv
# first transition mean :  348.889515041418
# last transition mean :  35.51076818764414

# %% [markdown]
# # PLC

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/plc_pid/data/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)

a = pd.read_csv(latest_file)

a['error'] = abs(a['sp'] - a['pv'])

first_transition = a.head(1500).tail(1000)
mean = first_transition["error"].mean()
print("first transition mean : " , mean)

last_transition = a.tail(1000)
mean = last_transition["error"].mean()
print("last transition mean : " , mean)
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(15,10))
plt.plot(b, first_transition['error'], c='r')
plt.savefig('plc_first_transition.png')
b = [x for x in range(len(first_transition))]

plt.figure(figsize=(15,10))
plt.plot(b, last_transition['error'], c='r')
plt.savefig('plc_last_transition.png')
# Out:
# C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/plc_pid/data\11_11_2020_01_54_07.csv
# first transition mean :  7.70920066791187
# last transition mean :  2.229026331569874

# %% [markdown]
# # All Agents

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/*/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv

mean_df = []

for file in list_of_files:
    a = pd.read_csv(file)    
    a['error'] = abs(a['sp'] - a['pv'])
    
    first_transition = a.head(1500).tail(1000)
    first_transition_mean = first_transition["error"].mean()
    #print("first transition mean : " , mean)
        
    last_transition = a.tail(1000)
    last_transition_mean = last_transition["error"].mean()  
    #print("last transition mean : " , mean)
    
    mean_df.append([first_transition_mean,last_transition_mean])
    

mean_df = pd.DataFrame(mean_df, columns=['first_transition_mean', 'last_transition_mean'])

print("first_transition_mean : ", mean_df['first_transition_mean'].mean() )
print("last_transition_mean : ", mean_df['last_transition_mean'].mean() )
print("max_of_first_transition_mean : ", mean_df['first_transition_mean'].max() )
print("max_of_last_transition_mean : ", mean_df['last_transition_mean'].max() )
print("min_of_first_transition_mean : ", mean_df['first_transition_mean'].min() )
print("min_of_last_transition_mean : ", mean_df['last_transition_mean'].min() )

ft_median = mean_df['first_transition_mean'].median()
lt_median = mean_df['last_transition_mean'].median() 
print("first_transition_median : ", ft_median )
print("last_transition_median : ", lt_median )

print("count_of_ft_mean_above_100 : ",mean_df[mean_df['first_transition_mean'].gt(ft_median)]['first_transition_mean'].count() )
print("count_of_ft_mean_below_100 : ",mean_df[mean_df['first_transition_mean'].lt(ft_median)]['first_transition_mean'].count() )

print("count_of_lt_mean_above_10 : ",mean_df[mean_df['last_transition_mean'].gt(lt_median)]['last_transition_mean'].count() )
print("count_of_lt_mean_below_10 : ",mean_df[mean_df['last_transition_mean'].lt(lt_median)]['last_transition_mean'].count() )
# Out:
# first_transition_mean :  3103.6105606530637
# last_transition_mean :  1805.4013590886223
# max_of_first_transition_mean :  388932.9452163223
# max_of_last_transition_mean :  17430.41147239566
# min_of_first_transition_mean :  0.18116336031464017
# min_of_last_transition_mean :  0.04831608111758942
# first_transition_median :  317.06552990046674
# last_transition_median :  38.65634284381748
# count_of_ft_mean_above_100 :  150
# count_of_ft_mean_below_100 :  150
# count_of_lt_mean_above_10 :  150
# count_of_lt_mean_below_10 :  150

# %% [markdown]
# # Mean of DQN

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/dqn/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv

mean_df = []

for file in list_of_files:
    a = pd.read_csv(file)    
    a['error'] = abs(a['sp'] - a['pv'])
    
    first_transition = a.head(1500).tail(1000)
    first_transition_mean = first_transition["error"].mean()
    #print("first transition mean : " , mean)
        
    last_transition = a.tail(1000)
    last_transition_mean = last_transition["error"].mean()  
    #print("last transition mean : " , mean)
    
    mean_df.append([first_transition_mean,last_transition_mean])
    

mean_df = pd.DataFrame(mean_df, columns=['first_transition_mean', 'last_transition_mean'])

print("first_transition_mean : ", mean_df['first_transition_mean'].mean() )
print("last_transition_mean : ", mean_df['last_transition_mean'].mean() )
print("first_transition_median : ", mean_df['first_transition_mean'].median() )
print("last_transition_median : ", mean_df['last_transition_mean'].median() )
print("max_of_first_transition_mean : ", mean_df['first_transition_mean'].max() )
print("max_of_last_transition_mean : ", mean_df['last_transition_mean'].max() )
print("min_of_first_transition_mean : ", mean_df['first_transition_mean'].min() )
print("min_of_last_transition_mean : ", mean_df['last_transition_mean'].min() )

print("count_of_ft_mean_above_median : ",mean_df[mean_df['first_transition_mean'].gt(ft_median)]['first_transition_mean'].count() )
print("count_of_ft_mean_below_median : ",mean_df[mean_df['first_transition_mean'].lt(ft_median)]['first_transition_mean'].count() )

print("count_of_lt_mean_above_median : ",mean_df[mean_df['last_transition_mean'].gt(lt_median)]['last_transition_mean'].count() )
print("count_of_lt_mean_below_median : ",mean_df[mean_df['last_transition_mean'].lt(lt_median)]['last_transition_mean'].count() )
# Out:
# first_transition_mean :  1004.9786380502123
# last_transition_mean :  24.264170194271607
# first_transition_median :  19.2098892231137
# last_transition_median :  21.612633946882266
# max_of_first_transition_mean :  10840.10455655735
# max_of_last_transition_mean :  71.16678777994278
# min_of_first_transition_mean :  0.317200920548712
# min_of_last_transition_mean :  0.6512327583128535
# count_of_ft_mean_above_median :  14
# count_of_ft_mean_below_median :  86
# count_of_lt_mean_above_median :  20
# count_of_lt_mean_below_median :  80

# %% [markdown]
# # Mean of SARSA

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/sarsa/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv

mean_df = []

for file in list_of_files:
    a = pd.read_csv(file)    
    a['error'] = abs(a['sp'] - a['pv'])
    
    first_transition = a.head(1500).tail(1000)
    first_transition_mean = first_transition["error"].mean()
    #print("first transition mean : " , mean)
        
    last_transition = a.tail(1000)
    last_transition_mean = last_transition["error"].mean()  
    #print("last transition mean : " , mean)
    
    mean_df.append([first_transition_mean,last_transition_mean])
    

mean_df = pd.DataFrame(mean_df, columns=['first_transition_mean', 'last_transition_mean'])

print("first_transition_mean : ", mean_df['first_transition_mean'].mean() )
print("last_transition_mean : ", mean_df['last_transition_mean'].mean() )
print("first_transition_median : ", mean_df['first_transition_mean'].median() )
print("last_transition_median : ", mean_df['last_transition_mean'].median() )
print("max_of_first_transition_mean : ", mean_df['first_transition_mean'].max() )
print("max_of_last_transition_mean : ", mean_df['last_transition_mean'].max() )
print("min_of_first_transition_mean : ", mean_df['first_transition_mean'].min() )
print("min_of_last_transition_mean : ", mean_df['last_transition_mean'].min() )

print("count_of_ft_mean_above_median : ",mean_df[mean_df['first_transition_mean'].gt(ft_median)]['first_transition_mean'].count() )
print("count_of_ft_mean_below_median : ",mean_df[mean_df['first_transition_mean'].lt(ft_median)]['first_transition_mean'].count() )

print("count_of_lt_mean_above_median : ",mean_df[mean_df['last_transition_mean'].gt(lt_median)]['last_transition_mean'].count() )
print("count_of_lt_mean_below_median : ",mean_df[mean_df['last_transition_mean'].lt(lt_median)]['last_transition_mean'].count() )
# Out:
# first_transition_mean :  7931.886387259463
# last_transition_mean :  4568.743473432035
# first_transition_median :  1717.6074169589942
# last_transition_median :  1399.097190828025
# max_of_first_transition_mean :  388932.9452163223
# max_of_last_transition_mean :  14942.375383382034
# min_of_first_transition_mean :  0.18116336031464017
# min_of_last_transition_mean :  0.5666378019175882
# count_of_ft_mean_above_median :  55
# count_of_ft_mean_below_median :  45
# count_of_lt_mean_above_median :  60
# count_of_lt_mean_below_median :  40

# %% [markdown]
# # Mean of CEM

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/drl_pid/dsc/cem/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv

mean_df = []

for file in list_of_files:
    a = pd.read_csv(file)    
    a['error'] = abs(a['sp'] - a['pv'])
    
    first_transition = a.head(1500).tail(1000)
    first_transition_mean = first_transition["error"].mean()
    #print("first transition mean : " , mean)
        
    last_transition = a.tail(1000)
    last_transition_mean = last_transition["error"].mean()  
    #print("last transition mean : " , mean)
    
    mean_df.append([first_transition_mean,last_transition_mean])
    

mean_df = pd.DataFrame(mean_df, columns=['first_transition_mean', 'last_transition_mean'])

print("first_transition_mean : ", mean_df['first_transition_mean'].mean() )
print("last_transition_mean : ", mean_df['last_transition_mean'].mean() )
print("first_transition_median : ", mean_df['first_transition_mean'].median() )
print("last_transition_median : ", mean_df['last_transition_mean'].median() )
print("max_of_first_transition_mean : ", mean_df['first_transition_mean'].max() )
print("max_of_last_transition_mean : ", mean_df['last_transition_mean'].max() )
print("min_of_first_transition_mean : ", mean_df['first_transition_mean'].min() )
print("min_of_last_transition_mean : ", mean_df['last_transition_mean'].min() )

print("count_of_ft_mean_above_median : ",mean_df[mean_df['first_transition_mean'].gt(ft_median)]['first_transition_mean'].count() )
print("count_of_ft_mean_below_median : ",mean_df[mean_df['first_transition_mean'].lt(ft_median)]['first_transition_mean'].count() )

print("count_of_lt_mean_above_median : ",mean_df[mean_df['last_transition_mean'].gt(lt_median)]['last_transition_mean'].count() )
print("count_of_lt_mean_below_median : ",mean_df[mean_df['last_transition_mean'].lt(lt_median)]['last_transition_mean'].count() )
# Out:
# first_transition_mean :  373.9666566495151
# last_transition_mean :  823.1964336395622
# first_transition_median :  369.0678487380094
# last_transition_median :  61.36667206997676
# max_of_first_transition_mean :  496.65953127852805
# max_of_last_transition_mean :  17430.41147239566
# min_of_first_transition_mean :  267.5008239578284
# min_of_last_transition_mean :  0.04831608111758942
# count_of_ft_mean_above_median :  81
# count_of_ft_mean_below_median :  19
# count_of_lt_mean_above_median :  70
# count_of_lt_mean_below_median :  30

# %%
path = 'C:/Users/lavisht/AppData/Local/Programs/Python/Python38/Lib/site-packages/pid_env/plc_pid/data/*'
list_of_files = glob.glob(path) # * means all if need specific format then *.csv

mean_df = []

for file in list_of_files:
    #print (file)
    a = pd.read_csv(file)    
    a['error'] = abs(a['sp'] - a['pv'])
    
    first_transition = a.head(1500).tail(1000)
    first_transition_mean = first_transition["error"].mean()
    #print("first transition mean : " , mean)
        
    last_transition = a.tail(1000)
    last_transition_mean = last_transition["error"].mean()  
    #print("last transition mean : " , mean)
    
    mean_df.append([first_transition_mean,last_transition_mean])
    

mean_df = pd.DataFrame(mean_df, columns=['first_transition_mean', 'last_transition_mean'])

print("first_transition_mean : ", mean_df['first_transition_mean'].mean() )
print("last_transition_mean : ", mean_df['last_transition_mean'].mean() )
print("first_transition_median : ", mean_df['first_transition_mean'].median() )
print("last_transition_median : ", mean_df['last_transition_mean'].median() )
print("max_of_first_transition_mean : ", mean_df['first_transition_mean'].max() )
print("max_of_last_transition_mean : ", mean_df['last_transition_mean'].max() )
print("min_of_first_transition_mean : ", mean_df['first_transition_mean'].min() )
print("min_of_last_transition_mean : ", mean_df['last_transition_mean'].min() )

print("count_of_ft_mean_above_median : ",mean_df[mean_df['first_transition_mean'].gt(ft_median)]['first_transition_mean'].count() )
print("count_of_ft_mean_below_median : ",mean_df[mean_df['first_transition_mean'].lt(ft_median)]['first_transition_mean'].count() )

print("count_of_lt_mean_above_median : ",mean_df[mean_df['last_transition_mean'].gt(lt_median)]['last_transition_mean'].count() )
print("count_of_lt_mean_below_median : ",mean_df[mean_df['last_transition_mean'].lt(lt_median)]['last_transition_mean'].count() )
# Out:
# first_transition_mean :  6.533467009898169
# last_transition_mean :  7.573558957177451
# first_transition_median :  6.326881302252777
# last_transition_median :  6.413182464269948
# max_of_first_transition_mean :  15.630619098303061
# max_of_last_transition_mean :  26.41910883090363
# min_of_first_transition_mean :  0.17700591159051873
# min_of_last_transition_mean :  0.10485026376441056
# count_of_ft_mean_above_median :  0
# count_of_ft_mean_below_median :  100
# count_of_lt_mean_above_median :  0
# count_of_lt_mean_below_median :  100
